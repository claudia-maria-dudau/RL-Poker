# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import sys
sys.path.append('/content/gdrive/Othercomputers/My Laptop/Facultate/AN 3/Semestrul 1/Introducere in Reinforcement Learning/RL-Poker')
sys.path.append('/content/gdrive/Othercomputers/My Laptop/Facultate/AN 3/Semestrul 1/Introducere in Reinforcement Learning/RL-Poker/src/neuron-poker')

# %%
from run_agents import run_dqn_agent

run_dqn_agent()
